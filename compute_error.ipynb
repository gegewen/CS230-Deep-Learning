# %%
from PIL import Image

# %%
import PIL
from PIL import Image
basewidth = 50
file=open('result.txt', 'w')
for i in range(1, 129):
    img = Image.open('/Users/gege/ML/results/pix2pix/output/' + str(i) + '.jpg')
    #wpercent = (basewidth / float(img.size[0]))
    #hsize = int((float(img.size[1]) * float(wpercent)))
    #img = img.resize((basewidth, hsize), PIL.Image.ANTIALIAS)
    # img.save('resize/' + str(i) + '_real_A.png')
    pix = img.load()
    print(pix)
    row,column=50,50
    for y in range(103, 103 + 50):
        for x in range(103, 103 + 50):
            pixel=pix[x,y]
            file.write(str(pixel[0]) + " ")
    file.write('\n')
file.close()

# %%
img = Image.open('/Users/shenghong/ML/results/new_result1/input.jpg')
pix = img.load()
row,column=50,50
for y in range(104, 104 + 50):
    for x in range(104, 104 + 50):
        print(pix[x,y])
# Out:
# (245, 245, 245)
# (242, 242, 242)
# (239, 239, 239)
# (238, 238, 238)
# (239, 239, 239)
# (241, 241, 241)
# (242, 242, 242)
# (242, 242, 242)
# (243, 243, 243)
# (238, 238, 238)
# (234, 234, 234)
# (235, 235, 235)
# (235, 235, 235)
# (235, 235, 235)
# (239, 239, 239)
# (245, 245, 245)
# (239, 239, 239)
# (239, 239, 239)
# (239, 239, 239)
# (239, 239, 239)
# (239, 239, 239)
# (239, 239, 239)
# (239, 239, 239)
# (239, 239, 239)
# (241, 241, 241)
# (243, 243, 243)
# (240, 240, 240)
# (234, 234, 234)
# (235, 235, 235)
# (241, 241, 241)
# (241, 241, 241)
# (237, 237, 237)
# (242, 242, 242)
# (243, 243, 243)
# (240, 240, 240)
# (237, 237, 237)
# (239, 239, 239)
# (245, 245, 245)
# (246, 246, 246)
# (243, 243, 243)
# (242, 242, 242)
# (244, 244, 244)
# (243, 243, 243)
# (239, 239, 239)
# (239, 239, 239)
# (243, 243, 243)
# (244, 244, 244)
# (242, 242, 242)
# (250, 250, 250)
# (243, 243, 243)
# (243, 243, 243)
# (241, 241, 241)
# (239, 239, 239)
# (239, 239, 239)
# (240, 240, 240)
# ...

# %%
basewidth = 50
for i in range(1, 17):
    img = Image.open('/Users/gege/ML/test2/image_square_pix2pix/test_latest/images/' + str(i) + '_fake_B.png')
    wpercent = (basewidth / float(img.size[0]))
    hsize = int((float(img.size[1]) * float(wpercent)))
    img = img.resize((basewidth, hsize), PIL.Image.ANTIALIAS)
    img.save('resize/' + str(i) + '_fake_B.png')

# %%
im = Image.open('resized_image.jpg') # Can be many different formats.
pix = im.load()

# %%
pix[0,1]
# Out:
# (230, 230, 230)

# %%
from PIL import Image
im=Image.open("thresh.jpg")
fil = open('file', 'w')
pixel = im.load()
row,column=im.size
for y in range(column)
    for x in range(row)
        pixel=pix[x,y]
        fil.write(str(pixel)+'\n')
fil.close()
